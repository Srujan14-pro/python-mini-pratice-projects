# %%
num1=50
num2=10
result=num1+num2
result2=num1-num2
result3=num1*num2
result4=num1/num2
result5=num1//num2
result6=num1%num2
result7=num1**num2
print(f"the addition between {num1}+{num2} is {result}" )
print(f"the sub between {num1}-{num2} is {result2}" )
print(f"the mul between {num1}*{num2} is {result3}" )
print(f"the div between {num1}/{num2} is {result4}" )
print(f"the floor div between {num1}//{num2} is {result5}" )
print(f"the modulo between {num1}%{num2} is {result6}" )
print(f"the expo between {num1}**{num2} is {result7}" )

# %%
num1=10.0
num2=2.0
result=num1+num2
result2=num1-num2
result3=num1*num2
result4=num1/num2
result5=num1//num2
result6=num1%num2
result7=num1**num2
print(f"the addition between {num1}+{num2} is {result}" )
print(f"the sub between {num1}-{num2} is {result2}" )
print(f"the mul between {num1}*{num2} is {result3}" )
print(f"the div between {num1}/{num2} is {result4}" )
print(f"the floor div between {num1}//{num2} is {result5}" )
print(f"the modulo between {num1}%{num2} is {result6}" )
print(f"the expo between {num1}**{num2} is {result7}" )

# %%
num1=4
num2=1.5
result=num1>num2
print(f"the result of {num1}> {num2} is {result}")

# %%
num1=20
num2=20
num1 is  num2

# %%
id(num1)

# %%
id(num2)

# %%
"o"   in "srujan"

# %%
a=1000
b=100
a>b or a<b

# %%
not((a>b)  and (9==9))

# %%
10 & 3

# %%
16 >> 4

# %%
16<<4

# %%
47 | 14

# %%
a=10
a+=4
a

# %%
name="vas"
place="hyderabad"
age=22
print("my name is " + name + " and im from " + place + " and my age is ",age)

# %%
name="innomatics research labs"
name[14::-4]

# %%
name="         srujan tinku         "
name.lower()

# %%
name.upper()

# %%
name.capitalize()

# %%
name.title()

# %%
name.swapcase()

# %%
name.rjust(20,'*')

# %%
name.strip()

# %%
name.find("r")

# %%
name.index("sr")

# %%
c="10"

# %%
c.isdigit()

# %%
c.isnumeric()

# %%
c.isdecimal()

# %%
a=[1,3,45]
print(a)
type(a)

# %%
a=list((1,"srujan",9.8))
print(a)
type(a)

# %%
a=[]
type(a)

# %%
a=0
if a>0:
    print("positive")
elif a<0:
    print("negative")
else :
    print("zero")

# %%
a=7
if a%2==0:
    print("even")
else:
    print("odd")

# %%
a=10
b=10
if a>b:
    print("a is larger")
elif b>a:
    print("b is larger")
else:
    print("num is equal")

# %%
a=19
b=18
c=1
if a>=b and a>=c:
    print("a is big or equal")
elif b>=a and b>=c:
    print("b is big or equal")
else :
    print("c is big or equal")

# %%
count=0
for i in range(1,101):
    if i % 3 ==0 and i % 5==0:
        count+=1
print(count)

# %%
count=0
for i in range(1,21):
    if i%2==0:
        count+=1
print(count)

# %%
sum=0
for i in range(1,101):
    if i%2==0:
        sum+=i
print(sum)

# %%
a=12345
while a//10:

# %%
print("srujan")

# %%
name=input("enter your name:")
age=int(input("enter your age:"))
print(name,age)
# Out:
# u
#  0
